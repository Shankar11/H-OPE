# %%
import http.client
import json

conn = http.client.HTTPSConnection("na-1-dev.api.opentext.com")

headersList = {
 "Accept": "*/*",
 "Content-Type": "application/json" 
}

payload = json.dumps({
    "client_id": "1Jw2E3VTie13tC7vsg9yX81qIUxCeiVN",
    "client_secret": "oO4zZ0zE2at2cy9P",
    "grant_type": "password",
    "username": "sshankar11@gmail.com",
    "password": "Welcome@123"
})

conn.request("POST", "/tenants/539e378b-c644-4455-8be6-4c2018ebf9f4/oauth2/token", payload, headersList)
response = conn.getresponse()
result = response.read()

# %%
jsnstr = json.loads(result.decode("utf-8"))

# %%
jsnstr['access_token']
# Out:
# 'eyJraWQiOiI1OTc0MmY4NDg3NGYyNzQ1YjIyNTUxYjg5MTY1YWE5Mzc2NWZiODE3IiwidHlwIjoiYXQrand0IiwiYWxnIjoiUlMyNTYifQ.....dYtFxx-K_n24Y4W8sZGa024lB_b_7ucMzgP8XUrNC-7X0EXkvWqKw73l6pMQj1A51dvZkogZqzrLUgE4Njfq1UtR_59MKqNKu8k2CGg7T3c-EnfWrAVjEPmfy3REL4khBdykR1hxW_kKU1lFESL6BLB96kEO4hd2x9zdcKRw_3790MEqf1DMVH3C-gJpmEkHloO9IFrdKmCYD3BjB-HpZ9KO55VwMnmYRaIUcfe74n6_JnxUhcKFeUz4bquZRh6lO8fsHlTSzgGfYw6H9_Cg3LiQf_3sKRpf_e5uEztpkIy_Jp_eVyWSX2zhYr6e9qLXZLhMx0GB0nvYl2DNLad-sw'

# %%
from configobj import ConfigObj
config = ConfigObj("transaction.config")
config.filename ="transaction.config"
config['bearer_token'] = jsnstr['access_token']
config.write()

# %%
import configparser
config = configparser.ConfigParser();
config.read("transaction.ini")
config['ACCESS']['bearer_token']
# Out:
# 'eyJraWQiOiI1OTc0MmY4NDg3NGYyNzQ1YjIyNTUxYjg5MTY1YWE5Mzc2NWZiODE3IiwidHlwIjoiYXQrand0IiwiYWxnIjoiUlMyNTYifQ.....dYtFxx-K_n24Y4W8sZGa024lB_b_7ucMzgP8XUrNC-7X0EXkvWqKw73l6pMQj1A51dvZkogZqzrLUgE4Njfq1UtR_59MKqNKu8k2CGg7T3c-EnfWrAVjEPmfy3REL4khBdykR1hxW_kKU1lFESL6BLB96kEO4hd2x9zdcKRw_3790MEqf1DMVH3C-gJpmEkHloO9IFrdKmCYD3BjB-HpZ9KO55VwMnmYRaIUcfe74n6_JnxUhcKFeUz4bquZRh6lO8fsHlTSzgGfYw6H9_Cg3LiQf_3sKRpf_e5uEztpkIy_Jp_eVyWSX2zhYr6e9qLXZLhMx0GB0nvYl2DNLad-sw'

# %%
import configparser
parser = configparser.ConfigParser()
parser.read('transaction.ini')
parser.set('ACCESS', 'bearer_token', jsnstr['access_token'])
with open('transaction.ini', 'w') as configfile:
    parser.write(configfile)

# %%
import http.client
import json

conn = http.client.HTTPSConnection("na-1-dev.api.opentext.com")

headersList = {
 "Accept": "*/*",
 "User-Agent": "Thunder Client (https://www.thunderclient.com)",
 "Authorization": "Bearer eyJraWQiOiI1OTc0MmY4NDg3NGYyNzQ1YjIyNTUxYjg5MTY1YWE5Mzc2NWZiODE3IiwidHlwIjoiYXQrand0IiwiYWxnIjoiUlMyNTYifQ.....ms7G7ib08x_JDKmfjhAoQNOr1l8OlBYQEpbpHh1RoO2_TyPJcW-r4wP8V3uF10WtdEjjAkG7q3vMC6IA_jJQbK_Ae-i5G0lVIAa0u5ywzipOfBDTmjlBqbdPnNG5qvn45lFlOvPYAcRPXw32LtR-pyLu8pAEJpVDcu552EeslEHiuaxz0UiDWaClBQh71_DIwiq4cUky3ep-WEoV0QZXVoqdUp5EHvX5XHqQSC8F2dStXj0yM2VUCr_9br_FOlwIOqmvWmLYKoSjwmqcO3uJFtJ6blXj1EGqE3XBfTYydWDDVWZWqrve8Vlbh2F6yTVsnO5ka6aBc2rIrIFDcwLD9Q",
 "Content-Type": "application/json" 
}

payload = json.dumps({
  "data": "...",
  "contentType": "image/jpg",
  "offset": 0
})

conn.request("POST", "/capture/cp-rest/v2/session/files/", payload, headersList)
response = conn.getresponse()
result = response.read()

print(result.decode("utf-8"))
# Out:
# {"returnStatus":{"status":200,"substatus":0,"code":"OK0000","message":"","server":"WS-S6dd603299b544d7881da33354c854358-7928HS"},
# "id":"F_27efdd670e7b4dd0a5af6af1f6aef047DAT",
# "contentType":"image/jpg",
# "src":"https://na-1-dev.api.opentext.com/capture/cp-rest/session/files/F_27efdd670e7b4dd0a5af6af1f6aef047DAT",
# "updated":"2023-10-29T17:18:52.6305420Z"
#
# }

# %%
jsnstr = json.loads(result.decode("utf-8"))
jsnstr['id']
